# %% [markdown]
# #CMD-GAN

# %%
from google.colab import drive
#drive.mount("/content/gdrive/", force_remount=True)
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import os
root_path = 'gdrive/My Drive/MINI_PROJECT' #phd/FSL_Model_keras'
# root_path = 'gdrive/My Drive/phd' #/kksFiles'
print(os.getcwd())
os.chdir(root_path)
# !ls
#jupyter notebook  --NotebookApp.allow_origin='https://colab.research.google.com'   --port=8888  --NotebookApp.port_retries=0
#Moreover We show that the overall common feature can be taken as dummy class for cluster boundary smoothing which improves the generalization.
# Out:
# /content
# 100_epochs.jpeg		 FSL_Generative_adversarial_encoder.ipynb  mini-imagenet-cache-val.pkl
# 115_epochs.jpeg		 generator_miniImagemet_layr1_layr2.h5	   Model
# 40_epochs.jpeg		 generator_miniImagemet_layr1_layr2.keras  new_100_epochs.jpeg
# batch_images.pkl	 mini-imagenet-cache-test.pkl		   standard_gan_generator.keras
# cmd_gan_generator.keras  mini-imagenet-cache-train.pkl		   wasserstein_gan_generator.keras

# %%
import tensorflow as tf
import math
import matplotlib.pyplot as plt
import os
import keras
import numpy as np
import numpy.random as rng
import random
import tensorflow
from tensorflow.keras import backend as K
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import  Sequential,load_model, Model, save_model
from tensorflow.keras.layers import *
from tensorflow.keras import regularizers as rg
from tensorflow.keras import callbacks as cb

#import tensorflow_probability as tfp

# %%
import cv2
import numpy as np
from scipy import signal

# %% [markdown]
# # Initialization

# %%
# lr = 0.001
# eps = 1e-12

# def W_init(shape,name=None):
#     """Initialize weights as in paper"""
#     values = rng.normal(loc=0,scale=1e-2,size=shape)
#     return K.variable(values,name=name)

# def b_init(shape,name=None):
#     """Initialize bias as in paper"""
#     values=rng.normal(loc=0.5,scale=1e-2,size=shape)
#     return K.variable(values,name=name)

# #build convnet to use in each siamese 'leg'
def conv_net(dim):
    convnet = Sequential()
    #convnet.add(tf.keras.layers.RandomFlip( mode=HORIZONTAL_AND_VERTICAL, seed=None, **kwargs))
    for i in range(4):

        convnet.add(Conv2D(64,(3,3),padding='same',input_shape=dim))
        convnet.add(BatchNormalization())
        convnet.add(Activation('relu'))
        convnet.add(MaxPooling2D())
    convnet.add(Flatten())
    #convnet.add(Normalization(mean=0., variance=1.))
    return convnet


# def normalise(xx):
#   global noise
#   std = tf.reshape(tf.math.reduce_std(xx,axis=1),(-1,1))
#   meanFeature = tf.reshape(tf.reduce_mean(xx,axis=1),(-1,1))
#   out_feature = (xx- meanFeature)/std
#   return out_feature


def proto_dist(x):  # Negative softmax distance measure
    feature, pred = x
    pred_dist = tf.reduce_sum(pred ** 2, axis=1, keepdims=True)
    feature_dist = tf.reduce_sum(feature ** 2, axis=1, keepdims=True)
    #print(pred_dist.shape);  print(feature_dist.shape)
    dot = tf.matmul(pred, tf.transpose(feature))
    #print(dot.shape)
    return tf.nn.softmax(-(tf.sqrt(pred_dist + tf.transpose(feature_dist) - 2 * dot)))

# def cosine_distances(x):
#     support, query_img=x
#     normalize_a = tf.nn.l2_normalize(support,1)
#     normalize_b = tf.nn.l2_normalize(query_img,1)
#     distance = tf.matmul(normalize_b, tf.transpose(normalize_a)) #, transpose_b=True
#     return distance

# def reduce_tensor(x):
#     y=tf.reduce_mean(x, axis=1)
#     return y

# def reshape_query(x):  # reshape query output to  dimention 64*query,1
#     y=tf.reshape(x, [-1, tf.shape(x)[-1]])
#     return y

# def Bias_net(dim):
#     model = Sequential()
#     model.add(Conv2D(filters = 16, kernel_size =(3,1),padding ='same', activation ='linear', input_shape = dim))
#     model.add(BatchNormalization())
#     model.add(Conv2D(filters = 8, kernel_size =(3,1),padding ='same', activation ='linear'))
#     model.add(BatchNormalization())
#     model.add(Conv2D(filters = 1, kernel_size =(3,1), padding ='same', activation='linear'))
#     return model

# %% [markdown]
# # load dataset

# %%
import pandas as pd
df = pd.read_pickle("mini-imagenet-cache-train.pkl")
x_train=np.array(df['image_data']); y_train = df['class_dict']
#x_train = np.reshape(np.mean(x_train,axis=3),(-1,84,84,1)).astype('float32')
x_train = np.reshape(x_train,(-1,84,84,3)).astype('float32')
x_train /=255 #(x_train1-127)/127
print(x_train.shape, len(y_train))
#.....................................................................
df = pd.read_pickle("mini-imagenet-cache-val.pkl")
x_val=df['image_data']; y_val = df['class_dict']
#x_val = np.reshape(np.mean(x_val,axis=3),(-1,84,84,1)).astype('float32')
x_val = np.reshape(x_val,(-1,84,84,3)).astype('float32')
x_val  /=255 #(x_val1-127)/127  # 255
print(x_val.shape, len(y_val))
#..........................................................
df = pd.read_pickle("mini-imagenet-cache-test.pkl")
x_test=df['image_data']; y_test = df['class_dict']
#x_test = np.reshape(np.mean(x_test,axis=3),(-1,84,84,1)).astype('float32')
x_test = np.reshape(x_test,(-1,84,84,3)).astype('float32')
x_test /= 255
#x_test=(x_test1-127)/127
print(x_test.shape, len(y_test))
# Out:
# (38400, 84, 84, 3) 64
# (9600, 84, 84, 3) 16
# (12000, 84, 84, 3) 20

# %% [markdown]
# # Mask

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create the mask
n = 84
mask = np.ones((n,n,3))*1.0

for i in range(n):
    for j in range(n):
        for k in range(3):
            mask[i,j,k] = np.round(np.tanh(((np.abs(n/2-i)+np.abs(n/2-j))/n)),2)

print(mask[n//2-2,n//2-2,:], np.max(mask))

# Create a figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Display the first mask (1 - mask)
axes[0].imshow(1 - mask)
axes[0].set_title("Inverted Mask Visualization")
axes[0].axis('off')  # Hide axes for better visualization

# Display the second mask (original mask)
axes[1].imshow(mask)
axes[1].set_title("Original Mask Visualization")
axes[1].axis('off')  # Hide axes for better visualization

# Show the plots
plt.show()
# Out:
# [0.05 0.05 0.05] 0.76

# %%
plt.imshow(x_train[600])

# %% [markdown]
# # Data generation for generator

# %%
k=0.01
#del LabelTrain, LabelVal, LabelTest,Data_GeneratorRaviLabel1,loadLabel1,Data_GeneratorRaviLabel
#del Data_GeneratorRaviLabel
randLayer=np.random.normal(0.1, 0.05,size=(84,84,3))
idxx=random.sample(list(y_test), 5)

# import cv2
# def flip (img):
#   img=np.reshape(img, (84,84,3))
#   img2= cv2.flip(img, 1)
#   return img2 #np.expand_dims(img2, axis=-1)
# s=5
# def cv2_zoom(img):
#     m,n,p=img.shape
#     cropped_img = img[s:m-s, s:n-s,:]
#     result = cv2.resize(cropped_img, (84, 84))
#     return result

class Data_GeneratorRaviLabel(tf.keras.utils.Sequence):

    #def __init__(self, datatype='train', dim=(32,32), n_channels=1, way=20, shot=1, query=1, num_batch=10):
    def __init__(self, datatype='train', dim=(84,84,1), num_per_class=1, n_channels=1, way = 3,shot=1, num_batch=10):
        'Initialization'
        global k,idxx, mask
        self.data=x_train
        self.y=y_train

        if(datatype=='val'):
          self.data=x_val
          self.y=y_val

        if(datatype=='test'):
          self.data=x_test
          self.y=y_test

        self.dim = dim
        self.n_channels = n_channels
        #print(num_per_class)
        self.num_batch = num_batch
        self.n_classes = len(self.data)
        self.on_epoch_end()
        self.shot = shot
        self.way = way
        #self.noise1=np.abs(np.random.normal(0,0.3,(84,84)))
        self.maskk=np.repeat(np.reshape(mask[:,:,:], (1,84,84,3)),self.way*self.shot, axis=0)

    def __len__(self):
        'Denotes the number of batches per epoch'
        return self.num_batch
    def __getitem__(self,index):
        'Generate one batch of data'
        X_query,  X_query1, X_query2 = self.__data_generation()
        return X_query, X_query1, X_query2

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        pass

    def __data_generation(self):
        X_sample=[]; X_query=[]; X_query1=[]; X_query2=[];
        idx=random.sample(list(self.y), self.way)
        label = np.zeros((self.way*self.shot, self.way))
        layr1 = random.sample([0,1,2], 1)[0]
        layr2 = (layr1+1)%3 #random.sample([0,1,2], 1)[0]

        for i in range(self.way):
          sample_idx1 = random.sample(self.y[idx[i]], 2*self.shot)

          for s in range(self.shot):
              imgg = self.data[sample_idx1[s]]
              X_query.append(imgg)
              img2 = imgg.copy()
              img01 = self.data[sample_idx1[self.shot+s]]  #  #
              #img2[:,:,layr2] = img01[:,:,layr2]
              #img2[:,:,layr2]=img2[:,:,layr2]*(1-mask[:,:,layr1])+ img01[:,:,layr2]*(mask[:,:,layr1]+0.1)
              #img2=img2*(1-mask)+ img01*(mask)
              img2=1.5*img2*(1-mask) - 0.5*(img2-img01*(mask))

              # img2 = img2 * (1 - mask) + img01 * mask * 0.7 + 0.3 * img2

              # alpha = 0.6  # Controls how much of img2 contributes outside the mask
              # beta = 0.8   # Controls how much of img01 contributes inside the mask
              # gamma = 0.2  # Residual blend factor

              # img2 = alpha * img2 * (1 - mask) + beta * img01 * mask + gamma * img2

              X_query1.append(img2)
              X_query2.append(img01)


        return  np.array(X_query), np.array(X_query1), np.array(X_query2)  #X_noise,
train_way = 5
shot = 2
n=600

val_loader = Data_GeneratorRaviLabel(datatype='train', num_per_class=n,way = train_way,shot=shot, num_batch=1)
x,y,z = val_loader[0]
print(x.shape,y.shape,z.shape)

img1,img2,img3=val_loader[0]
fig = plt.figure(figsize=(6,10))
p=3
for j in range(5):
    plt.subplot(5,p,p*j+1)
    plt.imshow(img1[j, :, :,:] )
    plt.subplot(5,p,p*j+2)
    plt.imshow(img2[j, :, :,:] )
    plt.subplot(5,p,p*j+3)
    plt.imshow(img3[j, :, :,:] )

    #plt.axis('off')
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (10, 84, 84, 3) (10, 84, 84, 3) (10, 84, 84, 3)

# %% [markdown]
# # Generator

# %%
def make_generator_model(dim):
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(64, (3,3),  padding='same', input_shape=dim))
    model.add(layers.LayerNormalization())
    model.add(layers.LeakyReLU())
    #model.add(augmentLayer())
    #model.add(layers.MaxPooling2D(2,2))
    model.add(layers.Conv2D(64,(3,3), padding='same'))
    model.add(layers.LayerNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2D(64,(3,3), padding='same'))
    model.add(layers.LayerNormalization())
    model.add(layers.LeakyReLU())
    model.add(layers.Conv2D(64,(1,1), padding='same'))
    model.add(layers.LayerNormalization())
    model.add(layers.LeakyReLU())
    model.add(layers.Conv2D(3, (1,1), padding='same',use_bias=False, activation='sigmoid'))

    #model.add(layers.ReLU())
    return model

dim=(84, 84, 3)
generator = make_generator_model(dim)
print(generator.summary())
noise=y #np.concatenate((x,y),3)
generated_image = np.abs(generator([noise], training=False))
plt.imshow(generated_image[0, :, :, 0], cmap='gray')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 84, 84, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer_normalization                  │ (None, 84, 84, 64)          │             128 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 84, 84, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 84, 84, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer_normalization_1                │ (None, 84, 84, 64)          │             128 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 84, 84, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 84, 84, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer_normalization_2                │ (None, 84, 84, 64)          │             128 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)            │ (None, 84, 84, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 84, 84, 64)          │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer_normalization_3                │ (None, 84, 84, 64)          │             128 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)            │ (None, 84, 84, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 84, 84, 3)           │             192 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 80,512 (314.50 KB)
#  Trainable params: 80,512 (314.50 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# #Discriminator

# %%
#del discriminator
def make_discriminator_model():  #576
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(64, (3,3), padding='valid',   input_shape=[84,84,3]))
    model.add(layers.LayerNormalization())
    model.add(layers.ReLU())
    model.add(layers.MaxPooling2D(2,2))

    model.add(layers.Conv2D(64, (3,3), padding='same'))
    model.add(layers.LayerNormalization())
    model.add(layers.ReLU())
    model.add(layers.MaxPooling2D(2,2))
    #model.add(Attention(ch=64))

    model.add(layers.Conv2D(64, (3,3), padding='same'))
    model.add(layers.LayerNormalization())
    model.add(layers.MaxPooling2D(2,2))
    model.add(layers.ReLU())
    model.add(layers.Dropout(0.1))

    model.add(layers.Conv2D(64, (1,1), padding='same'))
    model.add(layers.LayerNormalization())
    model.add(layers.MaxPooling2D(2,2))
    model.add(layers.Activation('tanh'))

    model.add(layers.Flatten())
    #model.add(layers.Dense(1, activation='sigmoid'))
    return model

discriminator = make_discriminator_model()
print(discriminator.summary())
img=tf.reshape(generated_image,(-1,84,84,3))
decision = discriminator(img)
print(np.max(decision),np.min(decision),np.mean(decision))
#print (decision)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)                    │ (None, 82, 82, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer_normalization_4                │ (None, 82, 82, 64)          │             128 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu (ReLU)                         │ (None, 82, 82, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 41, 41, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 41, 41, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer_normalization_5                │ (None, 41, 41, 64)          │             128 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_1 (ReLU)                       │ (None, 41, 41, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 20, 20, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 20, 20, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer_normalization_6                │ (None, 20, 20, 64)          │             128 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_2 (ReLU)                       │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 10, 10, 64)          │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer_normalization_7                │ (None, 10, 10, 64)          │             128 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1600)                │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 80,320 (313.75 KB)
#  Trainable params: 80,320 (313.75 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# 0.9864516 -0.99280006 0.10555966

# %% [markdown]
# #Saving Model

# %%
#generator.save('/content/gdrive/My Drive/MINI_PROJECT/generator_miniImagemet_layr1_layr2.keras')

# %% [markdown]
# #Loading Model

# %%
#generator = tf.keras.models.load_model('/content/gdrive/My Drive/MINI_PROJECT/generator_miniImagemet_layr1_layr2.keras')

# %% [markdown]
# #Standard GAN

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-5)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-5)
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)
dim=(84,84,3)
generator = make_generator_model(dim)
discriminator = make_discriminator_model()
generator1=generator
@tf.function
def train_step(image_batch1, image_batch2):
  #noise_dim=(image_batch1.shape[0],1000)

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
      dx = discriminator(image_batch2, training=True)

      noise= image_batch1 # tf.concat([image_batch1,image_batch2],3) #image_batch1*0.7+image_batch2*0.3 #
      gx = generator(noise, training=True)
      dgx = discriminator(gx, training=True)

      gen_loss =tf.reduce_mean(dgx) # cross_entropy(tf.ones_like(dgx)*0.8, dgx) #generator_loss(fake_output)+fake_loss1

      #disc_loss1 = cross_entropy(tf.ones_like(dx), dx)
      disc_loss = tf.reduce_mean(dx)-tf.reduce_mean(dgx) # disc_loss1 +  cross_entropy(tf.zeros_like(dgx), dgx)

  gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
  gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

  generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
  discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))
  return gen_loss, disc_loss

# %%
train_way = 5
shot = 10
num_batch=10
initial_learning_rate = 1e-5
#generator1= generator
def train( epochs):
  gen_loss=0; disc_loss=0;i=0;
  global gLoss, dLoss1, gLoss1, dLoss2
  for epoch in range(epochs):
    #start = time.time()
    gen_loss=0; disc_loss=0; disc_loss0=0
    dataset = Data_GeneratorRaviLabel(datatype='train', num_per_class=n,way = train_way,shot=shot, num_batch=10)
    #for image_batch1, image_batch2,image_batch3 in dataset:
    for j in range(len(dataset)):
       image_batch1, image_batch2,image_batch3 = dataset[j]
       gen_loss1, disc_loss1 = train_step(image_batch1, image_batch2)
       gen_loss +=gen_loss1; disc_loss += disc_loss1;
    i=i+1
    gen_loss = gen_loss/num_batch; disc_loss = disc_loss/num_batch;
    print(i,gen_loss, disc_loss)
    sgLoss1.append(gen_loss); sdLoss1.append(disc_loss);
EPOCHS = 100
sgLoss1=[]; sdLoss1=[];
train( EPOCHS)
# Out:
# 1 tf.Tensor(0.22081801, shape=(), dtype=float32) tf.Tensor(0.004615277, shape=(), dtype=float32)
# 2 tf.Tensor(0.21540384, shape=(), dtype=float32) tf.Tensor(0.010913978, shape=(), dtype=float32)
# 3 tf.Tensor(0.21226731, shape=(), dtype=float32) tf.Tensor(0.013325666, shape=(), dtype=float32)
# 4 tf.Tensor(0.21308872, shape=(), dtype=float32) tf.Tensor(0.010050366, shape=(), dtype=float32)
# 5 tf.Tensor(0.21941367, shape=(), dtype=float32) tf.Tensor(-0.0022516088, shape=(), dtype=float32)
# 6 tf.Tensor(0.22746928, shape=(), dtype=float32) tf.Tensor(-0.018201197, shape=(), dtype=float32)
# 7 tf.Tensor(0.2355167, shape=(), dtype=float32) tf.Tensor(-0.03329542, shape=(), dtype=float32)
# 8 tf.Tensor(0.24494287, shape=(), dtype=float32) tf.Tensor(-0.049122773, shape=(), dtype=float32)
# 9 tf.Tensor(0.25497, shape=(), dtype=float32) tf.Tensor(-0.066548154, shape=(), dtype=float32)
# 10 tf.Tensor(0.26642498, shape=(), dtype=float32) tf.Tensor(-0.07801083, shape=(), dtype=float32)
# 11 tf.Tensor(0.26100972, shape=(), dtype=float32) tf.Tensor(-0.07573796, shape=(), dtype=float32)
# 12 tf.Tensor(0.23045394, shape=(), dtype=float32) tf.Tensor(-0.042502698, shape=(), dtype=float32)
# 13 tf.Tensor(0.18346953, shape=(), dtype=float32) tf.Tensor(0.009581933, shape=(), dtype=float32)
# 14 tf.Tensor(0.1607297, shape=(), dtype=float32) tf.Tensor(0.033014696, shape=(), dtype=float32)
# 15 tf.Tensor(0.15526296, shape=(), dtype=float32) tf.Tensor(0.029788524, shape=(), dtype=float32)
# 16 tf.Tensor(0.1561152, shape=(), dtype=float32) tf.Tensor(0.02199903, shape=(), dtype=float32)
# 95 tf.Tensor(0.10828173, shape=(), dtype=float32) tf.Tensor(-0.0003448121, shape=(), dtype=float32)
# 96 tf.Tensor(0.110281624, shape=(), dtype=float32) tf.Tensor(-0.002745001, shape=(), dtype=float32)
# 97 tf.Tensor(0.11079655, shape=(), dtype=float32) tf.Tensor(-0.0013718635, shape=(), dtype=float32)
# 98 tf.Tensor(0.11233115, shape=(), dtype=float32) tf.Tensor(-0.0043596243, shape=(), dtype=float32)
# 99 tf.Tensor(0.113378264, shape=(), dtype=float32) tf.Tensor(-0.001773002, shape=(), dtype=float32)
# 100 tf.Tensor(0.113745846, shape=(), dtype=float32) tf.Tensor(-0.0024352171, shape=(), dtype=float32)

# %%
generator1.save('/content/gdrive/My Drive/MINI_PROJECT/standard_gan_generator.keras')

# %%
generator1 = tf.keras.models.load_model('/content/gdrive/My Drive/MINI_PROJECT/standard_gan_generator.keras')

# %%
import pickle
def saveData(data,file_name):
  open_file = open(file_name, "wb")
  pickle.dump(data, open_file)
  open_file.close()

def loadData(file_name):
  open_file = open(file_name, "rb")
  hist = pickle.load(open_file)
  open_file.close()
  return hist

# %%
saveData(sgLoss1,'Model/sgLoss11.npy' )
saveData(sdLoss1,'Model/sdLoss11.npy' )

# %% [markdown]
# #Wassertein GAN

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-5)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-5)
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)
dim=(84,84,3)
generator = make_generator_model(dim)
discriminator = make_discriminator_model()

#generator= load_model('Model/generator_miniImagemet_layr1_layr2.h5')
def cosine_distances1(x):
    support, query_img=x
    normalize_a = tf.nn.l2_normalize(support,1)
    normalize_b = tf.nn.l2_normalize(query_img,1)
    distance = tf.reduce_sum(normalize_b*normalize_a, axis=1) #tf.matmul(normalize_b, tf.transpose(normalize_a)) #, transpose_b=True
    return distance

@tf.function
def train_step(image_batch1, image_batch2):
  #noise_dim=(image_batch1.shape[0],1000)

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
      dxx = discriminator(image_batch2, training=True)
      dx = discriminator(image_batch1, training=True)

      noise= image_batch1 # tf.concat([image_batch1,image_batch2],3) #image_batch1*0.7+image_batch2*0.3 #
      gx = generator(noise, training=True)
      dgx = discriminator(gx, training=True)

      gen_dist1=cosine_distances1([dgx,dxx])
      gen_dist2=proto_dist([dgx,dx])

      dis_dist1 = proto_dist([dxx,dx])
      dis_dist2 = cosine_distances1([dxx,dxx])

      gen_loss1 = cross_entropy(tf.ones_like(gen_dist1), gen_dist1) #generator_loss(fake_output)+fake_loss1
      gen_loss = gen_loss1 + cross_entropy(tf.ones_like(gen_dist2)*0.5, gen_dist2)

      disc_loss1 = cross_entropy(tf.ones_like(dis_dist1)*0.5, dis_dist1) #discriminator_loss(real_output1, fake_output)
      disc_loss2 = cross_entropy(tf.ones_like(dis_dist2), dis_dist2)
      disc_loss = disc_loss1 + disc_loss2 + cross_entropy(tf.zeros_like(gen_dist1), gen_dist1)

  gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
  gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

  generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
  discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))
  return gen_loss, disc_loss, disc_loss1+disc_loss2
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
train_way = 10
shot = 1
num_batch=100

#generator1= generator
def train( epochs):
  gen_loss=0; disc_loss=0;i=0;
  global gLoss, dLoss1, gLoss1, dLoss2
  for epoch in range(epochs):
    #start = time.time()
    gen_loss=0; disc_loss=0; disc_loss0=0
    dataset = Data_GeneratorRaviLabel(datatype='train', num_per_class=n,way = train_way,shot=shot, num_batch=100)
    #for image_batch1, image_batch2,image_batch3 in dataset:
    for j in range(len(dataset)):
       image_batch1, image_batch2,image_batch3 = dataset[j]
       gen_loss1, disc_loss1, disc_loss11 = train_step(image_batch1, image_batch2)
       gen_loss +=gen_loss1; disc_loss += disc_loss1; disc_loss0 += disc_loss11
    i=i+1
    gen_loss = gen_loss/num_batch; disc_loss = disc_loss/num_batch; disc_loss0 = disc_loss0/num_batch
    print(i,gen_loss, disc_loss,disc_loss0)
    wgLoss1.append(gen_loss); wdLoss1.append(disc_loss); wdLoss2.append(disc_loss0)

EPOCHS = 100
wgLoss1=[]; wdLoss1=[];wdLoss2=[]

train( EPOCHS)
# Out:
# 1 tf.Tensor(1.0370576, shape=(), dtype=float32) tf.Tensor(2.2478702, shape=(), dtype=float32) tf.Tensor(1.0086058, shape=(), dtype=float32)
# 2 tf.Tensor(1.0762323, shape=(), dtype=float32) tf.Tensor(2.1598186, shape=(), dtype=float32) tf.Tensor(1.0087972, shape=(), dtype=float32)
# 3 tf.Tensor(1.0985473, shape=(), dtype=float32) tf.Tensor(2.1120436, shape=(), dtype=float32) tf.Tensor(1.0085459, shape=(), dtype=float32)
# 4 tf.Tensor(1.1093861, shape=(), dtype=float32) tf.Tensor(2.0902042, shape=(), dtype=float32) tf.Tensor(1.0084307, shape=(), dtype=float32)
# 5 tf.Tensor(1.1205444, shape=(), dtype=float32) tf.Tensor(2.067969, shape=(), dtype=float32) tf.Tensor(1.0082026, shape=(), dtype=float32)
# 6 tf.Tensor(1.1289458, shape=(), dtype=float32) tf.Tensor(2.0520773, shape=(), dtype=float32) tf.Tensor(1.0081443, shape=(), dtype=float32)
# 7 tf.Tensor(1.1365142, shape=(), dtype=float32) tf.Tensor(2.0381286, shape=(), dtype=float32) tf.Tensor(1.0081234, shape=(), dtype=float32)
# 8 tf.Tensor(1.1432499, shape=(), dtype=float32) tf.Tensor(2.026163, shape=(), dtype=float32) tf.Tensor(1.0081667, shape=(), dtype=float32)
# 9 tf.Tensor(1.1492302, shape=(), dtype=float32) tf.Tensor(2.015793, shape=(), dtype=float32) tf.Tensor(1.0082163, shape=(), dtype=float32)
# 10 tf.Tensor(1.1541698, shape=(), dtype=float32) tf.Tensor(2.0074239, shape=(), dtype=float32) tf.Tensor(1.0083444, shape=(), dtype=float32)
# 11 tf.Tensor(1.1574254, shape=(), dtype=float32) tf.Tensor(2.0022116, shape=(), dtype=float32) tf.Tensor(1.0085297, shape=(), dtype=float32)
# 12 tf.Tensor(1.1589918, shape=(), dtype=float32) tf.Tensor(1.9998641, shape=(), dtype=float32) tf.Tensor(1.008627, shape=(), dtype=float32)
# 13 tf.Tensor(1.1600155, shape=(), dtype=float32) tf.Tensor(1.9985957, shape=(), dtype=float32) tf.Tensor(1.0087228, shape=(), dtype=float32)
# 89 tf.Tensor(1.264319, shape=(), dtype=float32) tf.Tensor(1.8480973, shape=(), dtype=float32) tf.Tensor(1.0098761, shape=(), dtype=float32)
# 90 tf.Tensor(1.2647728, shape=(), dtype=float32) tf.Tensor(1.8474329, shape=(), dtype=float32) tf.Tensor(1.0099504, shape=(), dtype=float32)
# 91 tf.Tensor(1.2661068, shape=(), dtype=float32) tf.Tensor(1.8456142, shape=(), dtype=float32) tf.Tensor(1.009882, shape=(), dtype=float32)
# 92 tf.Tensor(1.2670188, shape=(), dtype=float32) tf.Tensor(1.844387, shape=(), dtype=float32) tf.Tensor(1.0099176, shape=(), dtype=float32)
# 93 tf.Tensor(1.2690643, shape=(), dtype=float32) tf.Tensor(1.8420295, shape=(), dtype=float32) tf.Tensor(1.0098779, shape=(), dtype=float32)
# 94 tf.Tensor(1.2690766, shape=(), dtype=float32) tf.Tensor(1.8418434, shape=(), dtype=float32) tf.Tensor(1.0099411, shape=(), dtype=float32)
# 95 tf.Tensor(1.2734216, shape=(), dtype=float32) tf.Tensor(1.8361675, shape=(), dtype=float32) tf.Tensor(1.0098214, shape=(), dtype=float32)
# 96 tf.Tensor(1.2725973, shape=(), dtype=float32) tf.Tensor(1.8374234, shape=(), dtype=float32) tf.Tensor(1.009932, shape=(), dtype=float32)
# 97 tf.Tensor(1.2746265, shape=(), dtype=float32) tf.Tensor(1.8348708, shape=(), dtype=float32) tf.Tensor(1.0099039, shape=(), dtype=float32)
# 98 tf.Tensor(1.2728453, shape=(), dtype=float32) tf.Tensor(1.8371114, shape=(), dtype=float32) tf.Tensor(1.0099541, shape=(), dtype=float32)
# 99 tf.Tensor(1.2773619, shape=(), dtype=float32) tf.Tensor(1.8313437, shape=(), dtype=float32) tf.Tensor(1.0099381, shape=(), dtype=float32)
# 100 tf.Tensor(1.2758521, shape=(), dtype=float32) tf.Tensor(1.8330296, shape=(), dtype=float32) tf.Tensor(1.0098293, shape=(), dtype=float32)

# %%
generator.save('/content/gdrive/My Drive/MINI_PROJECT/wasserstein_gan_generator.keras')

# %%
generator = tf.keras.models.load_model('/content/gdrive/My Drive/MINI_PROJECT/wasserstein_gan_generator.keras')

# %%
saveData(wgLoss1,'Model/wgLoss11.npy' )
saveData(wdLoss1,'Model/wdLoss11.npy' )

# %% [markdown]
# #CMD-GAN

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-5)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-5)
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)
dim=(84,84,6)
generator = make_generator_model(dim)
discriminator = make_discriminator_model()

#generator= load_model('Model/generator_miniImagemet_layr1_layr2.h5')
def cosine_distances1(x):
    support, query_img=x
    normalize_a = tf.nn.l2_normalize(support,1)
    normalize_b = tf.nn.l2_normalize(query_img,1)
    distance = tf.reduce_sum(normalize_b*normalize_a, axis=1) #tf.matmul(normalize_b, tf.transpose(normalize_a)) #, transpose_b=True
    return distance

@tf.function
def train_step(image_batch1, image_batch2,image_batch3):
  #noise_dim=(image_batch1.shape[0],1000)

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
      dxx = discriminator(image_batch2, training=True)
      dx = discriminator(image_batch1, training=True)
      #noise=np.concatenate((image_batch1, image_batch3), axis=1)
      noise=tf.concat((image_batch1, image_batch3), axis=-1)
      #noise= image_batch1 # tf.concat([image_batch1,image_batch2],3) #image_batch1*0.7+image_batch2*0.3 #
      gx = generator(noise, training=True)
      dgx = discriminator(gx, training=True)

      gen_dist1=cosine_distances1([dgx,dxx])
      gen_dist2=proto_dist([dgx,dx])

      dis_dist1 = proto_dist([dxx,dx])
      dis_dist2 = cosine_distances1([dxx,dxx])

      gen_loss1 = cross_entropy(tf.ones_like(gen_dist1), gen_dist1) #generator_loss(fake_output)+fake_loss1
      gen_loss = gen_loss1 + cross_entropy(tf.identity(gen_dist2), gen_dist2)

      disc_loss1 = cross_entropy(tf.identity(dis_dist1), dis_dist1) #discriminator_loss(real_output1, fake_output)
      disc_loss2 = cross_entropy(tf.ones_like(dis_dist2), dis_dist2)
      disc_loss = disc_loss1 + disc_loss2 + cross_entropy(tf.zeros_like(gen_dist1), gen_dist1)

  gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
  gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

  generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
  discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))
  return gen_loss, disc_loss, disc_loss1+disc_loss2

# %%
train_way = 10
shot = 1
num_batch=100

#generator1= generator
def train( epochs):
  gen_loss=0; disc_loss=0;i=0;
  global gLoss, dLoss1, gLoss1, dLoss2
  for epoch in range(epochs):
    #start = time.time()
    gen_loss=0; disc_loss=0; disc_loss0=0
    dataset = Data_GeneratorRaviLabel(datatype='train', num_per_class=n,way = train_way,shot=shot, num_batch=100)
    #for image_batch1, image_batch2,image_batch3 in dataset:
    for j in range(len(dataset)):
       image_batch1, image_batch2,image_batch3 = dataset[j]
       gen_loss1, disc_loss1, disc_loss11 = train_step(image_batch1, image_batch2,image_batch3)
       gen_loss +=gen_loss1; disc_loss += disc_loss1; disc_loss0 += disc_loss11
    i=i+1
    gen_loss = gen_loss/num_batch; disc_loss = disc_loss/num_batch; disc_loss0 = disc_loss0/num_batch
    print(i,gen_loss, disc_loss,disc_loss0)
    cmdgLoss1.append(gen_loss); cmddLoss1.append(disc_loss); cmddLoss2.append(disc_loss0)

EPOCHS = 100
cmdgLoss1=[]; cmddLoss1=[];cmddLoss2=[]

train( EPOCHS)
# Out:
# 1 tf.Tensor(1.0835468, shape=(), dtype=float32) tf.Tensor(2.2521126, shape=(), dtype=float32) tf.Tensor(1.0372199, shape=(), dtype=float32)
# 2 tf.Tensor(1.0782872, shape=(), dtype=float32) tf.Tensor(2.1921165, shape=(), dtype=float32) tf.Tensor(1.0172564, shape=(), dtype=float32)
# 3 tf.Tensor(1.0631144, shape=(), dtype=float32) tf.Tensor(2.1571627, shape=(), dtype=float32) tf.Tensor(1.0025258, shape=(), dtype=float32)
# 4 tf.Tensor(1.0673448, shape=(), dtype=float32) tf.Tensor(2.1223762, shape=(), dtype=float32) tf.Tensor(0.9941249, shape=(), dtype=float32)
# 5 tf.Tensor(1.0772145, shape=(), dtype=float32) tf.Tensor(2.0900445, shape=(), dtype=float32) tf.Tensor(0.98778397, shape=(), dtype=float32)
# 6 tf.Tensor(1.0813748, shape=(), dtype=float32) tf.Tensor(2.0766637, shape=(), dtype=float32) tf.Tensor(0.9872857, shape=(), dtype=float32)
# 7 tf.Tensor(1.0862378, shape=(), dtype=float32) tf.Tensor(2.067739, shape=(), dtype=float32) tf.Tensor(0.9887996, shape=(), dtype=float32)
# 8 tf.Tensor(1.0856687, shape=(), dtype=float32) tf.Tensor(2.066756, shape=(), dtype=float32) tf.Tensor(0.9903749, shape=(), dtype=float32)
# 9 tf.Tensor(1.0941724, shape=(), dtype=float32) tf.Tensor(2.0584855, shape=(), dtype=float32) tf.Tensor(0.9947245, shape=(), dtype=float32)
# 10 tf.Tensor(1.104445, shape=(), dtype=float32) tf.Tensor(2.0552254, shape=(), dtype=float32) tf.Tensor(1.0003475, shape=(), dtype=float32)
# 11 tf.Tensor(1.1153136, shape=(), dtype=float32) tf.Tensor(2.0494823, shape=(), dtype=float32) tf.Tensor(1.0034206, shape=(), dtype=float32)
# 12 tf.Tensor(1.1222483, shape=(), dtype=float32) tf.Tensor(2.0470877, shape=(), dtype=float32) tf.Tensor(1.0040535, shape=(), dtype=float32)
# 13 tf.Tensor(1.1299094, shape=(), dtype=float32) tf.Tensor(2.0437288, shape=(), dtype=float32) tf.Tensor(1.0060458, shape=(), dtype=float32)
# 14 tf.Tensor(1.131817, shape=(), dtype=float32) tf.Tensor(2.041565, shape=(), dtype=float32) tf.Tensor(1.005708, shape=(), dtype=float32)
# 15 tf.Tensor(1.1344875, shape=(), dtype=float32) tf.Tensor(2.0318358, shape=(), dtype=float32) tf.Tensor(1.0027666, shape=(), dtype=float32)
# 16 tf.Tensor(1.1315895, shape=(), dtype=float32) tf.Tensor(2.031235, shape=(), dtype=float32) tf.Tensor(1.0014784, shape=(), dtype=float32)
# 17 tf.Tensor(1.1308293, shape=(), dtype=float32) tf.Tensor(2.0275333, shape=(), dtype=float32) tf.Tensor(1.001308, shape=(), dtype=float32)
# 18 tf.Tensor(1.1328582, shape=(), dtype=float32) tf.Tensor(2.0254476, shape=(), dtype=float32) tf.Tensor(1.0000706, shape=(), dtype=float32)
# 19 tf.Tensor(1.1320215, shape=(), dtype=float32) tf.Tensor(2.0251527, shape=(), dtype=float32) tf.Tensor(0.997694, shape=(), dtype=float32)
# 20 tf.Tensor(1.1301776, shape=(), dtype=float32) tf.Tensor(2.0258963, shape=(), dtype=float32) tf.Tensor(1.0001248, shape=(), dtype=float32)
# 21 tf.Tensor(1.13256, shape=(), dtype=float32) tf.Tensor(2.0220494, shape=(), dtype=float32) tf.Tensor(0.9987392, shape=(), dtype=float32)
# 22 tf.Tensor(1.132034, shape=(), dtype=float32) tf.Tensor(2.0191948, shape=(), dtype=float32) tf.Tensor(0.9970926, shape=(), dtype=float32)
# 23 tf.Tensor(1.1330739, shape=(), dtype=float32) tf.Tensor(2.0220215, shape=(), dtype=float32) tf.Tensor(0.99996567, shape=(), dtype=float32)
# 24 tf.Tensor(1.1331562, shape=(), dtype=float32) tf.Tensor(2.02232, shape=(), dtype=float32) tf.Tensor(0.9980878, shape=(), dtype=float32)
# 99 tf.Tensor(1.2687327, shape=(), dtype=float32) tf.Tensor(1.8554642, shape=(), dtype=float32) tf.Tensor(1.0221214, shape=(), dtype=float32)
# 100 tf.Tensor(1.2651352, shape=(), dtype=float32) tf.Tensor(1.853575, shape=(), dtype=float32) tf.Tensor(1.0177325, shape=(), dtype=float32)

# %%
generator.save('/content/gdrive/My Drive/MINI_PROJECT/cmd_gan_generator.keras')

# %%
generator = tf.keras.models.load_model('/content/gdrive/My Drive/MINI_PROJECT/cmd_gan_generator.keras')

# %%
saveData(cmdgLoss1,'Model/cmdgLoss11.npy' )
saveData(cmddLoss1,'Model/cmddLoss11.npy' )

# %% [markdown]
# # Display

# %%
import pickle

# Extract a batch from the dataset
dataset = Data_GeneratorRaviLabel(way=train_way, datatype='train', shot=shot, num_batch=1)
(image1, image2, image3) = dataset[0]

# %%
# # Save the batch to a file
# with open('/content/gdrive/My Drive/MINI_PROJECT/batch_images.pkl', 'wb') as f:
#     pickle.dump((image1, image2, image3), f)

# %%
# with open('/content/gdrive/My Drive/MINI_PROJECT/batch_images.pkl', 'rb') as f:
#     image1, image2, image3 = pickle.load(f)


noise=tf.concat((image1, image3), axis=-1)
noise = noise[..., :3]
predictions = generator(noise, training=False)


fig= plt.figure(figsize=(10,20))
k=10;p=4
for i in range(k):
    plt.subplot(k, p, p*i+1)
    plt.imshow(image1[i, :, :,:])
    #plt.axis('off')
    plt.xlabel('Input')

    plt.subplot(k, p, p*i+2)
    plt.imshow(image3[i, :, :,:])
    #plt.axis('off')
    plt.xlabel('support')

    plt.subplot(k, p, p*i+3)
    plt.imshow(image2[i, :, :,:])
    #plt.axis('off')
    plt.xlabel('Masked')

    plt.subplot(k, p, p*i+4)
    plt.imshow(predictions[i, :, :,:], cmap='gray')
    #plt.axis('off')
    plt.xlabel('prediction')

#plt.savefig('image_at_epoch_{:04d}.png'.format(epoch))
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #Graph_Plotting

# %%
# sdl=loadData('Model/sdLoss11.npy')
# sgl=loadData('Model/sgLoss11.npy')

# wdl=loadData('Model/wdLoss11.npy')
# wgl=loadData('Model/wgLoss11.npy')

cmddl=loadData('Model/cmddLoss11.npy')
cmdgl=loadData('Model/cmdgLoss11.npy')

# plt.figure(figsize=(12,2))
# plt.subplot(1,3,1)
# plt.plot(sdl)
# plt.plot(sgl)
# plt.legend(["GAN Discriminator loss","GAN Generator loss"])

# plt.subplot(1,3,2)
# plt.plot(wdl)
# plt.plot(wgl)
# plt.legend(["W-GAN Discriminator loss","W-GAN Generator loss"])

# plt.subplot(1,3,3)
plt.plot(cmddl)
plt.plot(cmdgl)
plt.legend(["CMD-GAN Discriminator loss","CMD-GAN Generator loss"])

# plt.subplot(1,2,2)
# plt.plot(histProto['loss'])
# plt.plot(histProto['val_loss'])
# plt.plot(histSelf['loss'])
# plt.plot(histSelf['val_loss'])
# plt.plot(histCycle['loss'])
# plt.plot(histCycle['val_loss'])
# plt.legend(["Loss conv4","selfAttention","CycleAttention","val_loss_conv4","val_loss_selfAttention","val_loss_CycleAttention"])

plt.show()
